# %% [markdown]
# # Setup

# %%
# %run notebook_setup.py
# Out:
# Now you can import modules from the project root: /bi/workspace/Projects/Forecast/forecast

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.ticker import MultipleLocator
import seaborn as sns

# %%
from src.utils.create_week_date import add_week_start_date
from src.utils.read_data import read_data

# %%
import logging

from src.utils.setup_logging import setup_logging

from src.config.dir_config import OUTPUT_PATH_DEMAND_SUMMARY
from src.config.bigquery_config import CREDENTIALS_GBQ, PROJECT_ID_GBQ

# %% [markdown]
# # Read data

# %%
data_all = pd.read_parquet('../sandbox/data_genex_venta_transfer.parquet')

# %%
query = """
SELECT
  codigo_producto AS cod_producto,
  CONCAT('[', STRING_AGG(CONCAT("'", CAST(nom_talla AS STRING), "'"), ' ' ORDER BY codigo_talla ASC), ']') AS sizes,
  STRING_AGG(CAST(cantidad AS STRING), '' ORDER BY codigo_talla ASC) AS curva_sizes
FROM `proyecto_comercial_logistica.curva_producto` cp
LEFT JOIN `pbi_data.maestro_sku_procesado` ms
  ON cp.codigo_producto = ms.cod_producto AND
     cp.codigo_talla = ms.cod_talla
GROUP BY 1
"""

sizes_details = read_data(query,
                  PROJECT_ID_GBQ,
                  CREDENTIALS_GBQ,
                  fast_download=False)

dtypes = {
    'cod_producto': 'uint32',
    'sizes': 'category',
    'curva_sizes': 'category'
}

sizes_details = sizes_details.astype(dtypes)
# Out:
# Downloading: 100%|██████████|

# %% [markdown]
# # Analysis

# %%
import duckdb as ddb

con = ddb.connect()

# %%
data_all.head()
# Out:
#    cod_sucursal  cod_producto  cod_talla    cod_sku  cod_ano_comercial  \
# 0             1        272692        102  272692323               2024
# 1             1        272692        102  272692323               2024
# 2             1        272692        102  272692323               2024
# 3             1        272692        102  272692323               2025
# 4             1        272692        102  272692323               2025
#
#    cod_semana  mnt_precio_base  mnt_precio_vigente  weekly_sales  \
# 0          50          33990.0             16990.0             1
# 1          51          33990.0             16990.0             0
# 2          52          33990.0             16990.0             0
# 3           1          33990.0             16990.0             0
# 4           2          33990.0             16990.0             0
#
#    stock_start_week  ...  nom_talla   demand_type  clasificacion  \
# 0                 0  ...          S  Intermitente              C
# ...

# %%
sizes_details.head()
# Out:
#    cod_producto                                              sizes curva_sizes
# 0        210964  ['038' '040' '042' '044' '046' '048' '050' '052']    01234321
# 1        212429  ['038' '040' '042' '044' '046' '048' '050' '052']    01234321
# 2        191827              ['001' '002' '003' '6-9' '9-12' '3L']      122112
# 3        191828              ['001' '002' '003' '6-9' '9-12' '3L']      122112
# 4        191693              ['001' '002' '003' '6-9' '9-12' '3L']      122112

# %%
query = """
SELECT
  data_all.nombre_sucursal,  
  data_all.nombre_depto,
  data_all.nombre_linea,
  data_all.cod_producto,
  sizes_details.sizes,
  sizes_details.curva_sizes,
  data_all.cod_talla,
  data_all.nom_talla,
  data_all.week_start,
  data_all.week_number,
  clasif,
  can_final,
  ume,
  vta_promedio,
  factor,
  semana_vta,
FROM data_all
LEFT JOIN sizes_details
  ON data_all.cod_producto = sizes_details.cod_producto
WHERE data_all.nombre_depto = 'Lenceria'
  AND data_all.nombre_linea = 'Camisas de dormir'
  AND can_final > 0
"""

data = con.execute(query).df()

# %%
data_gb = data.groupby(['cod_talla','nom_talla','curva_sizes','clasif'], observed=True, as_index=False).agg(
    #products = ('cod_producto','nunique'),
    can_final = ('can_final','sum'),
    vta_promedio = ('vta_promedio','mean'),
    factor = ('factor','mean'),
    semana_vta = ('semana_vta','mean'),
    ume = ('ume','mean')
).round(2).copy()

data_gb['can_final_pct'] = (data_gb['can_final'] / data_gb.groupby(['curva_sizes','cod_talla'], observed=True)['can_final'].transform('sum')).round(4)

data_gb['curva_sizes'] = data_gb['curva_sizes'].astype('string')
data_gb['clasif'] = data_gb['clasif'].astype('string')

# %%
data_gb.query("nom_talla == 'M'")
# Out:
#    cod_talla nom_talla curva_sizes              clasif  can_final  \
# 0        103         M         111  BOTTOM INTELIGENTE     2659.0
# 1        103         M         111  BOTTOM TONTO            737.0
# 2        103         M         111             QUIEBRE       38.0
# 3        103         M         111      TOP INTELIGENT      410.0
# 4        103         M         111           TOP TONTO       65.0
# 5        103         M         321  BOTTOM INTELIGENTE     2104.0
# 6        103         M         321  BOTTOM TONTO            548.0
# 7        103         M         321             QUIEBRE        5.0
# 8        103         M         321      TOP INTELIGENT        4.0
#
#    vta_promedio  factor  semana_vta    ume  can_final_pct
# 0          1.81    1.77        7.36   8.34         0.6802
# 1          0.65    1.44        7.07   9.73         0.1885
# 2          1.00    2.00        8.00   4.00         0.0097
# 3          1.15    1.77        4.00   8.18         0.1049
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.ticker import MultipleLocator
import seaborn as sns

# --- Definir la talla fija ---
TALLA = "M"       # cámbiala solo si quieres otra
METRICA = "can_final_pct"   # usa "ume" si prefieres unidades

# --- Plot ---
plt.figure(figsize=(15,6))
sns.barplot(
    data=data_gb.query(f"nom_talla == '{TALLA}'"),
    x="clasif", y=METRICA, hue="curva_sizes"
)

plt.title(f"Distribución de repo automáticas por curva de tallas - Talla {TALLA}")
plt.xlabel("Clasificación")
plt.xticks(rotation=45, ha="right")
plt.legend(title="Curva de tallas")
plt.grid(False)

# Formato especial si es porcentaje
if METRICA == "can_final_pct":
    plt.ylim(0, 1)
    plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    plt.gca().yaxis.set_major_locator(MultipleLocator(0.1))

plt.show()
