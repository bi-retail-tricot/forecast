# %% [markdown]
# # Setup

# %%
# %run notebook_setup.py
# Out:
# Now you can import modules from the project root: /bi/workspace/Projects/Forecast/forecast

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.ticker import MultipleLocator
import seaborn as sns

# %%
from src.utils.create_week_date import add_week_start_date

# %% [markdown]
# # Read data

# %%
import duckdb

file = '../data/processed/trf_data_processed.parquet'
transfers = duckdb.query(f"SELECT * FROM '{file}' WHERE cod_sucursal = 24 and cod_producto = 680279 and cod_talla = 105").to_df()

transfers
# Out:
#    cod_sucursal  cod_producto  cod_talla  numero_trf          nombre_razon  \
# 0            24        680279        105     8769172        PREDISTRIBUIDA
# 1            24        680279        105     8769170        PREDISTRIBUIDA
# 2            24        680279        105     8769171        PREDISTRIBUIDA
# 3            24        680279        105     9111999  REPOSICION AUTOMATIC
#
#    cod_ano_comercial  cod_semana  fecha_apr_ini  fecha_des_ini  cantidad_apr  \
# 0               2025           9       20250226       20250317             4
# 1               2025           9       20250226       20250318             4
# 2               2025           9       20250226       20250318             4
# 3               2025          13       20250328       20250410             6
#
#    cantidad_can  cantidad_des    nombre_razon_group
# 0             0             4        PREDISTRIBUIDA
# 1             0             4        PREDISTRIBUIDA
# ...
